# %% [markdown]
# # 03 — Vegetation filter (HAG ≥ 2 m)

# %%
import subprocess, json
from pathlib import Path

ROOT = Path(".").resolve()
DATA = ROOT / "data"
PROC = DATA / "processed"
PIPES = ROOT / "pipelines"

LAS_HAG = PROC / "sample_hag.las"
LAS_VEG = PROC / "veg_gt2m.las"
PIPE_FILTER_VEG = PIPES / "pipeline_filter_veg.json"

assert LAS_HAG.exists(), f"Falta HAG: {LAS_HAG}. Corré 02_hag_processing.ipynb"
assert PIPE_FILTER_VEG.exists(), f"Falta pipeline: {PIPE_FILTER_VEG}. Corré 01_pipelines_setup.ipynb"

def run(cmd):
    print("$", " ".join(cmd))
    p = subprocess.run(cmd, capture_output=True, text=True)
    if p.stdout: print(p.stdout)
    if p.returncode != 0:
        print(p.stderr); raise RuntimeError("Fallo")
    return p.stdout

run(["pdal", "pipeline", str(PIPE_FILTER_VEG)])

all_info = run(["pdal", "info", str(LAS_VEG), "--all"])
print("¿veg_gt2m.las incluye HeightAboveGround?", "HeightAboveGround" in all_info)

summary = run(["pdal", "info", str(LAS_VEG), "--summary"])
meta = json.loads(summary)["summary"]["metadata"]
print(f"Formato LAS 1.{meta['minor_version']} / dataformat_id={meta['dataformat_id']}")
# Out:
# $ pdal pipeline /Users/cecilialedesma/Library/Mobile Documents/com~apple~CloudDocs/projects_2025/lidar_vegetation_classification/notebooks/pipelines/pipeline_filter_veg.json
# $ pdal info /Users/cecilialedesma/Library/Mobile Documents/com~apple~CloudDocs/projects_2025/lidar_vegetation_classification/notebooks/data/processed/veg_gt2m.las --all
# {
#   "boundary":
#   {
#     "area": 1036226.941,
#     "avg_pt_per_sq_unit": 0.612524372,
#     "avg_pt_spacing": 0.4522083468,
#     "boundary": "MULTIPOLYGON (((1843023.07367569 5443984.48304971,1843278.57655296 5443984.48304971,1843294.06157583 5443997.89347289,1843317.28911013 5443984.48304971,1843348.25915586 5443984.48304971,1843363.74417872 5443997.89347289,1843386.97171302 5443984.48304971,1843441.16929305 5443984.48304971,1843456.65431591 5443997.89347289,1843479.88185021 5443984.48304971,1843766.35477321 5443984.48304971,1843781.83979608 5443997.89347289,1843805.06733038 5443984.48304971,1843828.29486467 5443997.89347289,1843851.52239897 5443984.48304971,1843874.74993327 5443997.89347289,1843998.63011619 5443984.48304971,1844014.11513905 5444011.30389607,1844014.11513905 5444212.46024381,1843998.63011619 5444225.870667,1844014.11513905 5444239.28109018,1844010.24388334 5445010.38042318,1843061.78623285 5445003.67521159,1843061.78623285 5444976.85436523,1843046.30120999 5444963.44394204,1843050.1724657 5444943.32830727,1843034.68744284 5444929.91788409,1843038.55869855 5444909.80224931,1843023.07367569 5444896.39182613,1843026.9449314 5444876.27619136,1842988.23237424 5444809.22407544,1842988.23237424 5444004.59868448,1843023.07367569 5443984.48304971)),((1842999.84614139 5444882.98140295,1843015.33116426 5444896.39182613,1843011.45990854 5444916.5074609,1842988.23237424 5444889.68661454,1842999.84614139 5444882.98140295)))",
#     "boundary_json": { "type": "MultiPolygon", "coordinates": [ [ [ [ 5443984.483049710281193, 1843023.073675689985976 ], [ 5443984.483049710281193, 1843278.576552960090339 ], [ 5443997.893472890369594, 1843294.061575829982758 ], [ 5443984.483049710281193, 1843317.289110129931942 ], [ 5443984.483049710281193, 1843348.259155859937891 ], [ 5443997.893472890369594, 1843363.744178720051423 ], [ 5443984.483049710281193, 1843386.971713020000607 ], [ 5443984.483049710281193, 1843441.169293049955741 ], [ 5443997.893472890369594, 1843456.654315910069272 ], [ 5443984.483049710281193, 1843479.881850210018456 ], [ 5443984.483049710281193, 1843766.354773209895939 ], [ 5443997.893472890369594, 1843781.839796080021188 ], [ 5443984.483049710281193, 1843805.067330379970372 ], [ 5443997.893472890369594, 1843828.294864669907838 ], [ 5443984.483049710281193, 1843851.522398970089853 ], [ 5443997.893472890369594, 1843874.749933270039037 ], [ 5443984.483049710281193, 1843998.630116190062836 ], [ 5444011.303896070457995, 1844014.115139049943537 ], [ 5444212.460243809968233, 1844014.115139049943537 ], [ 5444225.870667000301182, 1843998.630116190062836 ], [ 5444239.281090180389583, 1844014.115139049943537 ], [ 5445010.380423179827631, 1844010.243883339921013 ], [ 5445003.67521158978343, 1843061.786232850048691 ], [ 5444976.854365229606628, 1843061.786232850048691 ], [ 5444963.443942040205002, 1843046.30120998993516 ], [ 5444943.328307270072401, 1843050.172465699957684 ], [ 5444929.917884089984, 1843034.687442840076983 ], [ 5444909.80224930960685, 1843038.558698550099507 ], [ 5444896.391826130449772, 1843023.073675689985976 ], [ 5444876.276191360317171, 1843026.9449314000085 ], [ 5444809.224075440317392, 1842988.232374239945784 ], [ 5444004.598684480413795, 1842988.232374239945784 ], [ 5443984.483049710281193, 1843023.073675689985976 ] ] ], [ [ [ 5444882.981402950361371, 1842999.846141390036792 ], [ 5444896.391826130449772, 1843015.33116425992921 ], [ 5444916.507460899651051, 1843011.459908539894968 ], [ 5444889.686614540405571, 1842988.232374239945784 ], [ 5444882.981402950361371, 1842999.846141390036792 ] ] ] ] },
#     "density": 4.890157551,
#     "edge_length": 0,
#     "estimated_edge": 13.41042318,
#     "hex_offsets": "MULTIPOINT (0 0, -3.87126 6.70521, 0 13.4104, 7.74251 13.4104, 11.6138 6.70521, 7.74251 0)",
#     "sample_size": 5000,
#     "threshold": 15
#   },
#   "file_size": 222964395,
#   "filename": "/Users/cecilialedesma/Library/Mobile Documents/com~apple~CloudDocs/projects_2025/lidar_vegetation_classification/notebooks/data/processed/veg_gt2m.las",
#   "metadata":
#   {
#     "comp_spatialreference": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#     "compressed": false,
#     "copc": false,
#     "count": 5067313,
#     "creation_doy": 269,
#     "creation_year": 2025,
#     "dataformat_id": 6,
#     "dataoffset": 2623,
#     "filesource_id": 0,
#     "global_encoding": 16,
#     "global_encoding_base64": "EAA=",
#     "header_size": 375,
#     "major_version": 1,
#     "maxx": 1844004.63,
#     "maxy": 5445003.19,
#     "maxz": 284.67,
#     "minor_version": 4,
#     "minx": 1842997.3,
#     "miny": 5443997.1,
#     "minz": 128.67,
#     "offset_x": 0,
#     "offset_y": 0,
#     "offset_z": 0,
#     "point_length": 44,
#     "project_id": "00000000-0000-0000-0000-000000000000",
#     "scale_x": 0.01,
#     "scale_y": 0.01,
#     "scale_z": 0.01,
#     "software_id": "PDAL 2.6.3 (Releas)",
#     "spatialreference": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#     "srs":
#     {
#       "compoundwkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#       "horizontal": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#       "isgeocentric": false,
#       "isgeographic": false,
#       "json": {
#   "type": "ProjectedCRS",
#   "name": "NZGD2000 / New Zealand Transverse Mercator 2000",
#   "base_crs": {
#     "name": "NZGD2000",
#     "datum": {
#       "type": "GeodeticReferenceFrame",
#       "name": "New Zealand Geodetic Datum 2000",
#       "ellipsoid": {
#         "name": "GRS 1980",
#         "semi_major_axis": 6378137,
#         "inverse_flattening": 298.257222101
#       }
#     },
#     "coordinate_system": {
#       "subtype": "ellipsoidal",
#       "axis": [
#         {
#           "name": "Geodetic latitude",
#           "abbreviation": "Lat",
#           "direction": "north",
#           "unit": "degree"
#         },
#         {
#           "name": "Geodetic longitude",
#           "abbreviation": "Lon",
#           "direction": "east",
#           "unit": "degree"
#         }
#       ]
#     },
#     "id": {
#       "authority": "EPSG",
#       "code": 4167
#     }
#   },
#   "conversion": {
#     "name": "unnamed",
#     "method": {
#       "name": "Transverse Mercator",
#       "id": {
#         "authority": "EPSG",
#         "code": 9807
#       }
#     },
#     "parameters": [
#       {
#         "name": "Latitude of natural origin",
#         "value": 0,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8801
#         }
#       },
#       {
#         "name": "Longitude of natural origin",
#         "value": 173,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8802
#         }
#       },
#       {
#         "name": "Scale factor at natural origin",
#         "value": 0.9996,
#         "unit": "unity",
#         "id": {
#           "authority": "EPSG",
#           "code": 8805
#         }
#       },
#       {
#         "name": "False easting",
#         "value": 1600000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8806
#         }
#       },
#       {
#         "name": "False northing",
#         "value": 10000000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8807
#         }
#       }
#     ]
#   },
#   "coordinate_system": {
#     "subtype": "Cartesian",
#     "axis": [
#       {
#         "name": "Northing",
#         "abbreviation": "",
#         "direction": "north",
#         "unit": "metre"
#       },
#       {
#         "name": "Easting",
#         "abbreviation": "",
#         "direction": "east",
#         "unit": "metre"
#       }
#     ]
#   },
#   "id": {
#     "authority": "EPSG",
#     "code": 2193
#   }
# },
#       "prettycompoundwkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",\n    GEOGCS[\"NZGD2000\",\n        DATUM[\"New_Zealand_Geodetic_Datum_2000\",\n            SPHEROID[\"GRS 1980\",6378137,298.257222101,\n                AUTHORITY[\"EPSG\",\"7019\"]],\n            AUTHORITY[\"EPSG\",\"6167\"]],\n        PRIMEM[\"Greenwich\",0,\n            AUTHORITY[\"EPSG\",\"8901\"]],\n        UNIT[\"degree\",0.0174532925199433,\n            AUTHORITY[\"EPSG\",\"9122\"]],\n        AUTHORITY[\"EPSG\",\"4167\"]],\n    PROJECTION[\"Transverse_Mercator\"],\n    PARAMETER[\"latitude_of_origin\",0],\n    PARAMETER[\"central_meridian\",173],\n    PARAMETER[\"scale_factor\",0.9996],\n    PARAMETER[\"false_easting\",1600000],\n    PARAMETER[\"false_northing\",10000000],\n    UNIT[\"metre\",1,\n        AUTHORITY[\"EPSG\",\"9001\"]],\n    AXIS[\"Northing\",NORTH],\n    AXIS[\"Easting\",EAST],\n    AUTHORITY[\"EPSG\",\"2193\"]]",
#       "prettywkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",\n    GEOGCS[\"NZGD2000\",\n        DATUM[\"New_Zealand_Geodetic_Datum_2000\",\n            SPHEROID[\"GRS 1980\",6378137,298.257222101,\n                AUTHORITY[\"EPSG\",\"7019\"]],\n            AUTHORITY[\"EPSG\",\"6167\"]],\n        PRIMEM[\"Greenwich\",0,\n            AUTHORITY[\"EPSG\",\"8901\"]],\n        UNIT[\"degree\",0.0174532925199433,\n            AUTHORITY[\"EPSG\",\"9122\"]],\n        AUTHORITY[\"EPSG\",\"4167\"]],\n    PROJECTION[\"Transverse_Mercator\"],\n    PARAMETER[\"latitude_of_origin\",0],\n    PARAMETER[\"central_meridian\",173],\n    PARAMETER[\"scale_factor\",0.9996],\n    PARAMETER[\"false_easting\",1600000],\n    PARAMETER[\"false_northing\",10000000],\n    UNIT[\"metre\",1,\n        AUTHORITY[\"EPSG\",\"9001\"]],\n    AXIS[\"Northing\",NORTH],\n    AXIS[\"Easting\",EAST],\n    AUTHORITY[\"EPSG\",\"2193\"]]",
#       "proj4": "+proj=tmerc +lat_0=0 +lon_0=173 +k=0.9996 +x_0=1600000 +y_0=10000000 +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs",
#       "units":
#       {
#         "horizontal": "metre",
#         "vertical": ""
#       },
#       "vertical": "",
#       "wkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]"
#     },
#     "system_id": "PDAL",
#     "vlr_0":
#     {
#       "data": "...",
#       "description": "Extra Bytes Record",
#       "record_id": 4,
#       "user_id": "LASF_Spec"
#     },
#     "vlr_1":
#     {
#       "data": "...",
#       "description": "OGC Transformation Record",
#       "record_id": 2112,
#       "user_id": "LASF_Projection"
#     },
#     "vlr_2":
#     {
#       "data": "...",
#       "description": "OGR variant of OpenGIS WKT SRS",
#       "record_id": 2112,
#       "user_id": "liblas"
#     }
#   },
#   "now": "2025-09-26T01:34:03-0300",
#   "pdal_version": "2.6.3 (git-version: Release)",
#   "reader": "readers.las",
#   "schema":
#   {
#     "dimensions":
#     [
#       {
#         "name": "X",
#         "size": 8,
#         "type": "floating"
#       },
#       {
#         "name": "Y",
#         "size": 8,
#         "type": "floating"
#       },
#       {
#         "name": "Z",
#         "size": 8,
#         "type": "floating"
#       },
#       {
#         "name": "Intensity",
#         "size": 2,
#         "type": "unsigned"
#       },
#       {
#         "name": "ReturnNumber",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "NumberOfReturns",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "ScanDirectionFlag",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "EdgeOfFlightLine",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "Classification",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "Synthetic",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "KeyPoint",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "Withheld",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "Overlap",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "ScanAngleRank",
#         "size": 4,
#         "type": "floating"
#       },
#       {
#         "name": "UserData",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "PointSourceId",
#         "size": 2,
#         "type": "unsigned"
#       },
#       {
#         "name": "GpsTime",
#         "size": 8,
#         "type": "floating"
#       },
#       {
#         "name": "ScanChannel",
#         "size": 1,
#         "type": "unsigned"
#       },
#       {
#         "name": "Red",
#         "size": 2,
#         "type": "unsigned"
#       },
#       {
#         "name": "Green",
#         "size": 2,
#         "type": "unsigned"
#       },
#       {
#         "name": "Blue",
#         "size": 2,
#         "type": "unsigned"
#       },
#       {
#         "name": "HeightAboveGround",
#         "size": 8,
#         "type": "floating"
#       }
#     ]
#   },
#   "stac":
#   {
#     "assets":
#     {
#       "data":
#       {
#         "href": "/Users/cecilialedesma/Library/Mobile Documents/com~apple~CloudDocs/projects_2025/lidar_vegetation_classification/notebooks/data/processed/veg_gt2m.las",
#         "title": "Pointcloud data"
#       }
#     },
#     "bbox":
#     [
#       175.8939775,
#       -41.11897694,
#       128.67,
#       175.9063591,
#       -41.10962376,
#       284.67
#     ],
#     "geometry": { "type": "Polygon", "coordinates": [ [ [ 175.894375390588095, -41.118976944715939, 128.67 ], [ 175.893977518512798, -41.109925610880715, 128.67 ], [ 175.90595959492822, -41.109623763043608, 284.67 ], [ 175.906359108689344, -41.118675001245393, 284.67 ], [ 175.894375390588095, -41.118976944715939, 128.67 ] ] ] },
#     "id": "veg_gt2m",
#     "links":
#     [
#       {
#         "href": "/Users/cecilialedesma/Library/Mobile Documents/com~apple~CloudDocs/projects_2025/lidar_vegetation_classification/notebooks/data/processed/veg_gt2m.las",
#         "rel": "derived_from"
#       }
#     ],
#     "properties":
#     {
#       "datetime": "2025-09-26T00:00:00Z",
#       "pc:count": 5067313,
#       "pc:encoding": ".las",
#       "pc:schemas":
#       [
#         {
#           "name": "X",
#           "size": 8,
#           "type": "floating"
#         },
#         {
#           "name": "Y",
#           "size": 8,
#           "type": "floating"
#         },
#         {
#           "name": "Z",
#           "size": 8,
#           "type": "floating"
#         },
#         {
#           "name": "Intensity",
#           "size": 2,
#           "type": "unsigned"
#         },
#         {
#           "name": "ReturnNumber",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "NumberOfReturns",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "ScanDirectionFlag",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "EdgeOfFlightLine",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "Classification",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "Synthetic",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "KeyPoint",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "Withheld",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "Overlap",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "ScanAngleRank",
#           "size": 4,
#           "type": "floating"
#         },
#         {
#           "name": "UserData",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "PointSourceId",
#           "size": 2,
#           "type": "unsigned"
#         },
#         {
#           "name": "GpsTime",
#           "size": 8,
#           "type": "floating"
#         },
#         {
#           "name": "ScanChannel",
#           "size": 1,
#           "type": "unsigned"
#         },
#         {
#           "name": "Red",
#           "size": 2,
#           "type": "unsigned"
#         },
#         {
#           "name": "Green",
#           "size": 2,
#           "type": "unsigned"
#         },
#         {
#           "name": "Blue",
#           "size": 2,
#           "type": "unsigned"
#         },
#         {
#           "name": "HeightAboveGround",
#           "size": 8,
#           "type": "floating"
#         }
#       ],
#       "pc:statistics":
#       [
#         {
#           "average": 1843507.803,
#           "count": 5067313,
#           "maximum": 1844004.63,
#           "minimum": 1842997.3,
#           "name": "X",
#           "position": 0,
#           "stddev": 287.2709786,
#           "variance": 82524.61515
#         },
#         {
#           "average": 5444510.962,
#           "count": 5067313,
#           "maximum": 5445003.19,
#           "minimum": 5443997.1,
#           "name": "Y",
#           "position": 1,
#           "stddev": 286.6818911,
#           "variance": 82186.50666
#         },
#         {
#           "average": 215.3941389,
#           "count": 5067313,
#           "maximum": 284.67,
#           "minimum": 128.67,
#           "name": "Z",
#           "position": 2,
#           "stddev": 25.26218929,
#           "variance": 638.1782079
#         },
#         {
#           "average": 10.6779818,
#           "count": 5067313,
#           "maximum": 39,
#           "minimum": 0,
#           "name": "Intensity",
#           "position": 3,
#           "stddev": 5.564234774,
#           "variance": 30.96070862
#         },
#         {
#           "average": 1.126334016,
#           "count": 5067313,
#           "maximum": 4,
#           "minimum": 1,
#           "name": "ReturnNumber",
#           "position": 4,
#           "stddev": 0.3415100898,
#           "variance": 0.1166291414
#         },
#         {
#           "average": 1.500319992,
#           "count": 5067313,
#           "maximum": 4,
#           "minimum": 1,
#           "name": "NumberOfReturns",
#           "position": 5,
#           "stddev": 0.6459882932,
#           "variance": 0.4173008749
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "ScanDirectionFlag",
#           "position": 6,
#           "stddev": 0,
#           "variance": 0
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "EdgeOfFlightLine",
#           "position": 7,
#           "stddev": 0,
#           "variance": 0
#         },
#         {
#           "average": 2.004055206,
#           "count": 5067313,
#           "maximum": 4,
#           "minimum": 1,
#           "name": "Classification",
#           "position": 8,
#           "stddev": 1.4156409,
#           "variance": 2.004039157
#         },
#         {
#           "average": 3.258381167,
#           "count": 5067313,
#           "maximum": 127.0019989,
#           "minimum": -124.9980011,
#           "name": "ScanAngleRank",
#           "position": 9,
#           "stddev": 74.74935233,
#           "variance": 5587.465674
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "UserData",
#           "position": 10,
#           "stddev": 0,
#           "variance": 0
#         },
#         {
#           "average": 2.772208072,
#           "count": 5067313,
#           "maximum": 6,
#           "minimum": 0,
#           "name": "PointSourceId",
#           "position": 11,
#           "stddev": 1.976518435,
#           "variance": 3.906625124
#         },
#         {
#           "average": 43.97986053,
#           "count": 5067313,
#           "maximum": 179,
#           "minimum": 14,
#           "name": "Red",
#           "position": 12,
#           "stddev": 11.79551319,
#           "variance": 139.1341314
#         },
#         {
#           "average": 73.76616226,
#           "count": 5067313,
#           "maximum": 168,
#           "minimum": 47,
#           "name": "Green",
#           "position": 13,
#           "stddev": 8.127683925,
#           "variance": 66.05924598
#         },
#         {
#           "average": 70.80993694,
#           "count": 5067313,
#           "maximum": 178,
#           "minimum": 48,
#           "name": "Blue",
#           "position": 14,
#           "stddev": 10.90627379,
#           "variance": 118.946808
#         },
#         {
#           "average": 43.46760176,
#           "count": 5067313,
#           "maximum": 43.534808,
#           "minimum": 43.451867,
#           "name": "GpsTime",
#           "position": 15,
#           "stddev": 0.03061026873,
#           "variance": 0.0009369885516
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "ScanChannel",
#           "position": 16,
#           "stddev": 0,
#           "variance": 0
#         },
#         {
#           "average": 18.89737537,
#           "count": 5067313,
#           "maximum": 41.52380486,
#           "minimum": 2,
#           "name": "HeightAboveGround",
#           "position": 17,
#           "stddev": 5.621017575,
#           "variance": 31.59583858
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "Synthetic",
#           "position": 18,
#           "stddev": 0,
#           "variance": 0
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "KeyPoint",
#           "position": 19,
#           "stddev": 0,
#           "variance": 0
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "Withheld",
#           "position": 20,
#           "stddev": 0,
#           "variance": 0
#         },
#         {
#           "average": 0,
#           "count": 5067313,
#           "maximum": 0,
#           "minimum": 0,
#           "name": "Overlap",
#           "position": 21,
#           "stddev": 0,
#           "variance": 0
#         }
#       ],
#       "pc:type": "lidar",
#       "proj:bbox":
#       [
#         1842997.3,
#         5443997.1,
#         128.67,
#         1844004.63,
#         5445003.19,
#         284.67
#       ],
#       "proj:geometry": { "type": "Polygon", "coordinates": [ [ [ 1842997.3, 5443997.100000000558794, 128.67 ], [ 1842997.3, 5445003.190000000409782, 128.67 ], [ 1844004.630000000121072, 5445003.190000000409782, 284.67 ], [ 1844004.630000000121072, 5443997.100000000558794, 284.67 ], [ 1842997.3, 5443997.100000000558794, 128.67 ] ] ] },
#       "proj:projjson": {
#   "type": "ProjectedCRS",
#   "name": "NZGD2000 / New Zealand Transverse Mercator 2000",
#   "base_crs": {
#     "name": "NZGD2000",
#     "datum": {
#       "type": "GeodeticReferenceFrame",
#       "name": "New Zealand Geodetic Datum 2000",
#       "ellipsoid": {
#         "name": "GRS 1980",
#         "semi_major_axis": 6378137,
#         "inverse_flattening": 298.257222101
#       }
#     },
#     "coordinate_system": {
#       "subtype": "ellipsoidal",
#       "axis": [
#         {
#           "name": "Geodetic latitude",
#           "abbreviation": "Lat",
#           "direction": "north",
#           "unit": "degree"
#         },
#         {
#           "name": "Geodetic longitude",
#           "abbreviation": "Lon",
#           "direction": "east",
#           "unit": "degree"
#         }
#       ]
#     },
#     "id": {
#       "authority": "EPSG",
#       "code": 4167
#     }
#   },
#   "conversion": {
#     "name": "unnamed",
#     "method": {
#       "name": "Transverse Mercator",
#       "id": {
#         "authority": "EPSG",
#         "code": 9807
#       }
#     },
#     "parameters": [
#       {
#         "name": "Latitude of natural origin",
#         "value": 0,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8801
#         }
#       },
#       {
#         "name": "Longitude of natural origin",
#         "value": 173,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8802
#         }
#       },
#       {
#         "name": "Scale factor at natural origin",
#         "value": 0.9996,
#         "unit": "unity",
#         "id": {
#           "authority": "EPSG",
#           "code": 8805
#         }
#       },
#       {
#         "name": "False easting",
#         "value": 1600000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8806
#         }
#       },
#       {
#         "name": "False northing",
#         "value": 10000000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8807
#         }
#       }
#     ]
#   },
#   "coordinate_system": {
#     "subtype": "Cartesian",
#     "axis": [
#       {
#         "name": "Northing",
#         "abbreviation": "",
#         "direction": "north",
#         "unit": "metre"
#       },
#       {
#         "name": "Easting",
#         "abbreviation": "",
#         "direction": "east",
#         "unit": "metre"
#       }
#     ]
#   },
#   "id": {
#     "authority": "EPSG",
#     "code": 2193
#   }
# },
#       "proj:wkt2": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]"
#     },
#     "stac_extensions":
#     [
#       "https://stac-extensions.github.io/pointcloud/v1.0.0/schema.json",
#       "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#     ],
#     "stac_version": "1.0.0",
#     "type": "Feature"
#   },
#   "stats":
#   {
#     "bbox":
#     {
#       "EPSG:4326":
#       {
#         "bbox":
#         {
#           "maxx": 175.9063591,
#           "maxy": -41.10962376,
#           "maxz": 284.67,
#           "minx": 175.8939775,
#           "miny": -41.11897694,
#           "minz": 128.67
#         },
#         "boundary": { "type": "Polygon", "coordinates": [ [ [ 175.894375390588095, -41.118976944715939, 128.67 ], [ 175.893977518512798, -41.109925610880715, 128.67 ], [ 175.90595959492822, -41.109623763043608, 284.67 ], [ 175.906359108689344, -41.118675001245393, 284.67 ], [ 175.894375390588095, -41.118976944715939, 128.67 ] ] ] }
#       },
#       "native":
#       {
#         "bbox":
#         {
#           "maxx": 1844004.63,
#           "maxy": 5445003.19,
#           "maxz": 284.67,
#           "minx": 1842997.3,
#           "miny": 5443997.1,
#           "minz": 128.67
#         },
#         "boundary": { "type": "Polygon", "coordinates": [ [ [ 1842997.3, 5443997.100000000558794, 128.67 ], [ 1842997.3, 5445003.190000000409782, 128.67 ], [ 1844004.630000000121072, 5445003.190000000409782, 284.67 ], [ 1844004.630000000121072, 5443997.100000000558794, 284.67 ], [ 1842997.3, 5443997.100000000558794, 128.67 ] ] ] }
#       }
#     },
#     "statistic":
#     [
#       {
#         "average": 1843507.803,
#         "count": 5067313,
#         "maximum": 1844004.63,
#         "minimum": 1842997.3,
#         "name": "X",
#         "position": 0,
#         "stddev": 287.2709786,
#         "variance": 82524.61515
#       },
#       {
#         "average": 5444510.962,
#         "count": 5067313,
#         "maximum": 5445003.19,
#         "minimum": 5443997.1,
#         "name": "Y",
#         "position": 1,
#         "stddev": 286.6818911,
#         "variance": 82186.50666
#       },
#       {
#         "average": 215.3941389,
#         "count": 5067313,
#         "maximum": 284.67,
#         "minimum": 128.67,
#         "name": "Z",
#         "position": 2,
#         "stddev": 25.26218929,
#         "variance": 638.1782079
#       },
#       {
#         "average": 10.6779818,
#         "count": 5067313,
#         "maximum": 39,
#         "minimum": 0,
#         "name": "Intensity",
#         "position": 3,
#         "stddev": 5.564234774,
#         "variance": 30.96070862
#       },
#       {
#         "average": 1.126334016,
#         "count": 5067313,
#         "maximum": 4,
#         "minimum": 1,
#         "name": "ReturnNumber",
#         "position": 4,
#         "stddev": 0.3415100898,
#         "variance": 0.1166291414
#       },
#       {
#         "average": 1.500319992,
#         "count": 5067313,
#         "maximum": 4,
#         "minimum": 1,
#         "name": "NumberOfReturns",
#         "position": 5,
#         "stddev": 0.6459882932,
#         "variance": 0.4173008749
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "ScanDirectionFlag",
#         "position": 6,
#         "stddev": 0,
#         "variance": 0
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "EdgeOfFlightLine",
#         "position": 7,
#         "stddev": 0,
#         "variance": 0
#       },
#       {
#         "average": 2.004055206,
#         "count": 5067313,
#         "maximum": 4,
#         "minimum": 1,
#         "name": "Classification",
#         "position": 8,
#         "stddev": 1.4156409,
#         "variance": 2.004039157
#       },
#       {
#         "average": 3.258381167,
#         "count": 5067313,
#         "maximum": 127.0019989,
#         "minimum": -124.9980011,
#         "name": "ScanAngleRank",
#         "position": 9,
#         "stddev": 74.74935233,
#         "variance": 5587.465674
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "UserData",
#         "position": 10,
#         "stddev": 0,
#         "variance": 0
#       },
#       {
#         "average": 2.772208072,
#         "count": 5067313,
#         "maximum": 6,
#         "minimum": 0,
#         "name": "PointSourceId",
#         "position": 11,
#         "stddev": 1.976518435,
#         "variance": 3.906625124
#       },
#       {
#         "average": 43.97986053,
#         "count": 5067313,
#         "maximum": 179,
#         "minimum": 14,
#         "name": "Red",
#         "position": 12,
#         "stddev": 11.79551319,
#         "variance": 139.1341314
#       },
#       {
#         "average": 73.76616226,
#         "count": 5067313,
#         "maximum": 168,
#         "minimum": 47,
#         "name": "Green",
#         "position": 13,
#         "stddev": 8.127683925,
#         "variance": 66.05924598
#       },
#       {
#         "average": 70.80993694,
#         "count": 5067313,
#         "maximum": 178,
#         "minimum": 48,
#         "name": "Blue",
#         "position": 14,
#         "stddev": 10.90627379,
#         "variance": 118.946808
#       },
#       {
#         "average": 43.46760176,
#         "count": 5067313,
#         "maximum": 43.534808,
#         "minimum": 43.451867,
#         "name": "GpsTime",
#         "position": 15,
#         "stddev": 0.03061026873,
#         "variance": 0.0009369885516
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "ScanChannel",
#         "position": 16,
#         "stddev": 0,
#         "variance": 0
#       },
#       {
#         "average": 18.89737537,
#         "count": 5067313,
#         "maximum": 41.52380486,
#         "minimum": 2,
#         "name": "HeightAboveGround",
#         "position": 17,
#         "stddev": 5.621017575,
#         "variance": 31.59583858
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "Synthetic",
#         "position": 18,
#         "stddev": 0,
#         "variance": 0
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "KeyPoint",
#         "position": 19,
#         "stddev": 0,
#         "variance": 0
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "Withheld",
#         "position": 20,
#         "stddev": 0,
#         "variance": 0
#       },
#       {
#         "average": 0,
#         "count": 5067313,
#         "maximum": 0,
#         "minimum": 0,
#         "name": "Overlap",
#         "position": 21,
#         "stddev": 0,
#         "variance": 0
#       }
#     ]
#   }
# }
#
# ¿veg_gt2m.las incluye HeightAboveGround? True
# $ pdal info /Users/cecilialedesma/Library/Mobile Documents/com~apple~CloudDocs/projects_2025/lidar_vegetation_classification/notebooks/data/processed/veg_gt2m.las --summary
# {
#   "file_size": 222964395,
#   "filename": "/Users/cecilialedesma/Library/Mobile Documents/com~apple~CloudDocs/projects_2025/lidar_vegetation_classification/notebooks/data/processed/veg_gt2m.las",
#   "now": "2025-09-26T01:34:03-0300",
#   "pdal_version": "2.6.3 (git-version: Release)",
#   "reader": "readers.las",
#   "summary":
#   {
#     "bounds":
#     {
#       "maxx": 1844004.63,
#       "maxy": 5445003.19,
#       "maxz": 284.67,
#       "minx": 1842997.3,
#       "miny": 5443997.1,
#       "minz": 128.67
#     },
#     "dimensions": "X, Y, Z, Intensity, ReturnNumber, NumberOfReturns, ScanDirectionFlag, EdgeOfFlightLine, Classification, Synthetic, KeyPoint, Withheld, Overlap, ScanAngleRank, UserData, PointSourceId, GpsTime, ScanChannel, Red, Green, Blue, HeightAboveGround",
#     "metadata":
#     {
#       "comp_spatialreference": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#       "compressed": false,
#       "copc": false,
#       "count": 5067313,
#       "creation_doy": 269,
#       "creation_year": 2025,
#       "dataformat_id": 6,
#       "dataoffset": 2623,
#       "filesource_id": 0,
#       "global_encoding": 16,
#       "global_encoding_base64": "EAA=",
#       "header_size": 375,
#       "major_version": 1,
#       "maxx": 1844004.63,
#       "maxy": 5445003.19,
#       "maxz": 284.67,
#       "minor_version": 4,
#       "minx": 1842997.3,
#       "miny": 5443997.1,
#       "minz": 128.67,
#       "offset_x": 0,
#       "offset_y": 0,
#       "offset_z": 0,
#       "point_length": 44,
#       "project_id": "00000000-0000-0000-0000-000000000000",
#       "scale_x": 0.01,
#       "scale_y": 0.01,
#       "scale_z": 0.01,
#       "software_id": "PDAL 2.6.3 (Releas)",
#       "spatialreference": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#       "srs":
#       {
#         "compoundwkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#         "horizontal": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#         "isgeocentric": false,
#         "isgeographic": false,
#         "json": {
#   "type": "ProjectedCRS",
#   "name": "NZGD2000 / New Zealand Transverse Mercator 2000",
#   "base_crs": {
#     "name": "NZGD2000",
#     "datum": {
#       "type": "GeodeticReferenceFrame",
#       "name": "New Zealand Geodetic Datum 2000",
#       "ellipsoid": {
#         "name": "GRS 1980",
#         "semi_major_axis": 6378137,
#         "inverse_flattening": 298.257222101
#       }
#     },
#     "coordinate_system": {
#       "subtype": "ellipsoidal",
#       "axis": [
#         {
#           "name": "Geodetic latitude",
#           "abbreviation": "Lat",
#           "direction": "north",
#           "unit": "degree"
#         },
#         {
#           "name": "Geodetic longitude",
#           "abbreviation": "Lon",
#           "direction": "east",
#           "unit": "degree"
#         }
#       ]
#     },
#     "id": {
#       "authority": "EPSG",
#       "code": 4167
#     }
#   },
#   "conversion": {
#     "name": "unnamed",
#     "method": {
#       "name": "Transverse Mercator",
#       "id": {
#         "authority": "EPSG",
#         "code": 9807
#       }
#     },
#     "parameters": [
#       {
#         "name": "Latitude of natural origin",
#         "value": 0,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8801
#         }
#       },
#       {
#         "name": "Longitude of natural origin",
#         "value": 173,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8802
#         }
#       },
#       {
#         "name": "Scale factor at natural origin",
#         "value": 0.9996,
#         "unit": "unity",
#         "id": {
#           "authority": "EPSG",
#           "code": 8805
#         }
#       },
#       {
#         "name": "False easting",
#         "value": 1600000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8806
#         }
#       },
#       {
#         "name": "False northing",
#         "value": 10000000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8807
#         }
#       }
#     ]
#   },
#   "coordinate_system": {
#     "subtype": "Cartesian",
#     "axis": [
#       {
#         "name": "Northing",
#         "abbreviation": "",
#         "direction": "north",
#         "unit": "metre"
#       },
#       {
#         "name": "Easting",
#         "abbreviation": "",
#         "direction": "east",
#         "unit": "metre"
#       }
#     ]
#   },
#   "id": {
#     "authority": "EPSG",
#     "code": 2193
#   }
# },
#         "prettycompoundwkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",\n    GEOGCS[\"NZGD2000\",\n        DATUM[\"New_Zealand_Geodetic_Datum_2000\",\n            SPHEROID[\"GRS 1980\",6378137,298.257222101,\n                AUTHORITY[\"EPSG\",\"7019\"]],\n            AUTHORITY[\"EPSG\",\"6167\"]],\n        PRIMEM[\"Greenwich\",0,\n            AUTHORITY[\"EPSG\",\"8901\"]],\n        UNIT[\"degree\",0.0174532925199433,\n            AUTHORITY[\"EPSG\",\"9122\"]],\n        AUTHORITY[\"EPSG\",\"4167\"]],\n    PROJECTION[\"Transverse_Mercator\"],\n    PARAMETER[\"latitude_of_origin\",0],\n    PARAMETER[\"central_meridian\",173],\n    PARAMETER[\"scale_factor\",0.9996],\n    PARAMETER[\"false_easting\",1600000],\n    PARAMETER[\"false_northing\",10000000],\n    UNIT[\"metre\",1,\n        AUTHORITY[\"EPSG\",\"9001\"]],\n    AXIS[\"Northing\",NORTH],\n    AXIS[\"Easting\",EAST],\n    AUTHORITY[\"EPSG\",\"2193\"]]",
#         "prettywkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",\n    GEOGCS[\"NZGD2000\",\n        DATUM[\"New_Zealand_Geodetic_Datum_2000\",\n            SPHEROID[\"GRS 1980\",6378137,298.257222101,\n                AUTHORITY[\"EPSG\",\"7019\"]],\n            AUTHORITY[\"EPSG\",\"6167\"]],\n        PRIMEM[\"Greenwich\",0,\n            AUTHORITY[\"EPSG\",\"8901\"]],\n        UNIT[\"degree\",0.0174532925199433,\n            AUTHORITY[\"EPSG\",\"9122\"]],\n        AUTHORITY[\"EPSG\",\"4167\"]],\n    PROJECTION[\"Transverse_Mercator\"],\n    PARAMETER[\"latitude_of_origin\",0],\n    PARAMETER[\"central_meridian\",173],\n    PARAMETER[\"scale_factor\",0.9996],\n    PARAMETER[\"false_easting\",1600000],\n    PARAMETER[\"false_northing\",10000000],\n    UNIT[\"metre\",1,\n        AUTHORITY[\"EPSG\",\"9001\"]],\n    AXIS[\"Northing\",NORTH],\n    AXIS[\"Easting\",EAST],\n    AUTHORITY[\"EPSG\",\"2193\"]]",
#         "proj4": "+proj=tmerc +lat_0=0 +lon_0=173 +k=0.9996 +x_0=1600000 +y_0=10000000 +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs",
#         "units":
#         {
#           "horizontal": "metre",
#           "vertical": ""
#         },
#         "vertical": "",
#         "wkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]"
#       },
#       "system_id": "PDAL",
#       "vlr_0":
#       {
#         "data": "...",
#         "description": "Extra Bytes Record",
#         "record_id": 4,
#         "user_id": "LASF_Spec"
#       },
#       "vlr_1":
#       {
#         "data": "...",
#         "description": "OGC Transformation Record",
#         "record_id": 2112,
#         "user_id": "LASF_Projection"
#       },
#       "vlr_2":
#       {
#         "data": "...",
#         "description": "OGR variant of OpenGIS WKT SRS",
#         "record_id": 2112,
#         "user_id": "liblas"
#       }
#     },
#     "num_points": 5067313,
#     "srs":
#     {
#       "compoundwkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#       "horizontal": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]",
#       "isgeocentric": false,
#       "isgeographic": false,
#       "json": {
#   "type": "ProjectedCRS",
#   "name": "NZGD2000 / New Zealand Transverse Mercator 2000",
#   "base_crs": {
#     "name": "NZGD2000",
#     "datum": {
#       "type": "GeodeticReferenceFrame",
#       "name": "New Zealand Geodetic Datum 2000",
#       "ellipsoid": {
#         "name": "GRS 1980",
#         "semi_major_axis": 6378137,
#         "inverse_flattening": 298.257222101
#       }
#     },
#     "coordinate_system": {
#       "subtype": "ellipsoidal",
#       "axis": [
#         {
#           "name": "Geodetic latitude",
#           "abbreviation": "Lat",
#           "direction": "north",
#           "unit": "degree"
#         },
#         {
#           "name": "Geodetic longitude",
#           "abbreviation": "Lon",
#           "direction": "east",
#           "unit": "degree"
#         }
#       ]
#     },
#     "id": {
#       "authority": "EPSG",
#       "code": 4167
#     }
#   },
#   "conversion": {
#     "name": "unnamed",
#     "method": {
#       "name": "Transverse Mercator",
#       "id": {
#         "authority": "EPSG",
#         "code": 9807
#       }
#     },
#     "parameters": [
#       {
#         "name": "Latitude of natural origin",
#         "value": 0,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8801
#         }
#       },
#       {
#         "name": "Longitude of natural origin",
#         "value": 173,
#         "unit": "degree",
#         "id": {
#           "authority": "EPSG",
#           "code": 8802
#         }
#       },
#       {
#         "name": "Scale factor at natural origin",
#         "value": 0.9996,
#         "unit": "unity",
#         "id": {
#           "authority": "EPSG",
#           "code": 8805
#         }
#       },
#       {
#         "name": "False easting",
#         "value": 1600000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8806
#         }
#       },
#       {
#         "name": "False northing",
#         "value": 10000000,
#         "unit": "metre",
#         "id": {
#           "authority": "EPSG",
#           "code": 8807
#         }
#       }
#     ]
#   },
#   "coordinate_system": {
#     "subtype": "Cartesian",
#     "axis": [
#       {
#         "name": "Northing",
#         "abbreviation": "",
#         "direction": "north",
#         "unit": "metre"
#       },
#       {
#         "name": "Easting",
#         "abbreviation": "",
#         "direction": "east",
#         "unit": "metre"
#       }
#     ]
#   },
#   "id": {
#     "authority": "EPSG",
#     "code": 2193
#   }
# },
#       "prettycompoundwkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",\n    GEOGCS[\"NZGD2000\",\n        DATUM[\"New_Zealand_Geodetic_Datum_2000\",\n            SPHEROID[\"GRS 1980\",6378137,298.257222101,\n                AUTHORITY[\"EPSG\",\"7019\"]],\n            AUTHORITY[\"EPSG\",\"6167\"]],\n        PRIMEM[\"Greenwich\",0,\n            AUTHORITY[\"EPSG\",\"8901\"]],\n        UNIT[\"degree\",0.0174532925199433,\n            AUTHORITY[\"EPSG\",\"9122\"]],\n        AUTHORITY[\"EPSG\",\"4167\"]],\n    PROJECTION[\"Transverse_Mercator\"],\n    PARAMETER[\"latitude_of_origin\",0],\n    PARAMETER[\"central_meridian\",173],\n    PARAMETER[\"scale_factor\",0.9996],\n    PARAMETER[\"false_easting\",1600000],\n    PARAMETER[\"false_northing\",10000000],\n    UNIT[\"metre\",1,\n        AUTHORITY[\"EPSG\",\"9001\"]],\n    AXIS[\"Northing\",NORTH],\n    AXIS[\"Easting\",EAST],\n    AUTHORITY[\"EPSG\",\"2193\"]]",
#       "prettywkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",\n    GEOGCS[\"NZGD2000\",\n        DATUM[\"New_Zealand_Geodetic_Datum_2000\",\n            SPHEROID[\"GRS 1980\",6378137,298.257222101,\n                AUTHORITY[\"EPSG\",\"7019\"]],\n            AUTHORITY[\"EPSG\",\"6167\"]],\n        PRIMEM[\"Greenwich\",0,\n            AUTHORITY[\"EPSG\",\"8901\"]],\n        UNIT[\"degree\",0.0174532925199433,\n            AUTHORITY[\"EPSG\",\"9122\"]],\n        AUTHORITY[\"EPSG\",\"4167\"]],\n    PROJECTION[\"Transverse_Mercator\"],\n    PARAMETER[\"latitude_of_origin\",0],\n    PARAMETER[\"central_meridian\",173],\n    PARAMETER[\"scale_factor\",0.9996],\n    PARAMETER[\"false_easting\",1600000],\n    PARAMETER[\"false_northing\",10000000],\n    UNIT[\"metre\",1,\n        AUTHORITY[\"EPSG\",\"9001\"]],\n    AXIS[\"Northing\",NORTH],\n    AXIS[\"Easting\",EAST],\n    AUTHORITY[\"EPSG\",\"2193\"]]",
#       "proj4": "+proj=tmerc +lat_0=0 +lon_0=173 +k=0.9996 +x_0=1600000 +y_0=10000000 +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs",
#       "units":
#       {
#         "horizontal": "metre",
#         "vertical": ""
#       },
#       "vertical": "",
#       "wkt": "PROJCS[\"NZGD2000 / New Zealand Transverse Mercator 2000\",GEOGCS[\"NZGD2000\",DATUM[\"New_Zealand_Geodetic_Datum_2000\",SPHEROID[\"GRS 1980\",6378137,298.257222101,AUTHORITY[\"EPSG\",\"7019\"]],AUTHORITY[\"EPSG\",\"6167\"]],PRIMEM[\"Greenwich\",0,AUTHORITY[\"EPSG\",\"8901\"]],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]],AUTHORITY[\"EPSG\",\"4167\"]],PROJECTION[\"Transverse_Mercator\"],PARAMETER[\"latitude_of_origin\",0],PARAMETER[\"central_meridian\",173],PARAMETER[\"scale_factor\",0.9996],PARAMETER[\"false_easting\",1600000],PARAMETER[\"false_northing\",10000000],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Northing\",NORTH],AXIS[\"Easting\",EAST],AUTHORITY[\"EPSG\",\"2193\"]]"
#     }
#   }
# }
#
# Formato LAS 1.4 / dataformat_id=6
